# %%
import pandas as pd

df=pd.read_csv('kc_house_data.csv')

#statement that changes the datetime object to a date object 
df['date'] = pd.to_datetime(df['date']).dt.date

df2=df.iloc[0]
print(df2)

df2=df.iloc[[0]]
print(df2)

df2=df.iloc[[0, 3]]
print(df2)

df2=df.iloc[0:7]
print(df2)

df2=df.iloc[[0, 2], [1, 3]]
print(df2)

df2=df.iloc[[0, 23],[1,3]]
print(df2)

df.iloc[:, 7] 
print(df2)

df2=df.loc[(df['sqft_living'] > 2500) & (df['price'] < 300000)]
print(df2)

df2=df.loc[(df['sqft_living'] > 2500) & (df['price'] < 300000) & (df['bedrooms']>3)]
print(df2)

df2=df.loc[(df['sqft_living'] > 2500) & (df['price'] < 300000) & (df['bedrooms']>3) & (df['bathrooms']>=3)]
print(df2)

df2=df.loc[(df['sqft_living'] > 2500) & (df['price'] < 300000) | (df['bedrooms']>3) & (df['bathrooms']>=3)]
print(df2)
# Out:
# id               7129300520
# date             2014-10-13
# price                221900
# bedrooms                  3
# bathrooms                 1
# sqft_living            1180
# sqft_lot               5650
# floors                    1
# waterfront                0
# view                      0
# condition                 3
# grade                     7
# sqft_above             1180
# sqft_basement             0
# yr_built               1955
# yr_renovated              0
# zipcode               98178
# lat                 47.5112
# long               -122.257
# sqft_living15          1340
# sqft_lot15             5650
# Name: 0, dtype: object
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  2014-10-13  221900.0         3        1.0         1180
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
#
# ...
